# %% [markdown]
# ## Importing Libraries

# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Data

# %%
# Importing the file
hotel_bookings = pd.read_csv('hotel_booking.csv')

# %% [markdown]
# ## EDA and Data Cleaning

# %%
# Top 5 rows
hotel_bookings.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
# Last 5 rows
hotel_bookings.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Checkng dimension
hotel_bookings.shape
# Out:
# (119390, 36)

# %%
# Checking columns
hotel_bookings.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
# Checking dtypes and overview of the data
hotel_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Changing datatype from object -> Datetime
hotel_bookings["reservation_status_date"] = pd.to_datetime(hotel_bookings["reservation_status_date"])

# %%
hotel_bookings["reservation_status_date"]
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 119390, dtype: datetime64[ns]

# %%
# Checking mathematical summary
hotel_bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Checking object dtype summary
hotel_bookings.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
# Checking unique values
for col in hotel_bookings.describe(include = 'object').columns:
    print(col)
    print(hotel_bookings[col].unique())
    print("-"*100)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ----------------------------------------------------------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ----------------------------------------------------------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ----------------------------------------------------------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
# ...

# %%
# Checking null values
hotel_bookings.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Removing columns with many null values
hotel_bookings.drop(['agent','company'],axis=1,inplace=True)

# %%
# Removing rows with NA's for the rest
hotel_bookings.dropna(inplace=True)

# %%
hotel_bookings.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
hotel_bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Removing some outliers
hotel_bookings=hotel_bookings[hotel_bookings['adr']<5000]

# %%
# Cancelation %
cancelled_perc = hotel_bookings['is_canceled'].value_counts(normalize=True)
cancelled_perc
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
plot = sns.countplot(x='is_canceled', data = hotel_bookings)

# Changing xticks
xtick_loc = plot.get_xticks()
xtick_labels = plot.get_xticklabels()

# Set the x-axis ticks
plot.set_xticks(ticks = xtick_loc, labels = ["Not Canceled", "Canceled"])

# %%
plt.figure(figsize=(8,4))
plot = sns.countplot(x="hotel",hue="is_canceled", data = hotel_bookings, palette = "Blues")
plt.title("Reservation Status in different hotels")
plt.xlabel("Hotel")
plt.ylabel("Number of reservations")
plt.legend(["not canceled","canceled"])
plt.show()

# %% [markdown]
# We can see the fact that city hotels have more bookings, but more cancelation rate as well

# %%
resort_hotel_pricing = hotel_bookings[hotel_bookings["hotel"]=="Resort Hotel"].groupby("reservation_status_date")[['adr']].mean()
city_hotel_pricing = hotel_bookings[hotel_bookings["hotel"]=="City Hotel"].groupby("reservation_status_date")[['adr']].mean()

# %%
plt.figure(figsize=(20,10))
plt.title("Avg Daily Rate for resort and city hotel",fontsize = 20)
plt.plot(resort_hotel_pricing.index,resort_hotel_pricing["adr"])
plt.plot(city_hotel_pricing.index,city_hotel_pricing["adr"])

# %% [markdown]
# The above graphs clears the fact that adr i.e. average daily rate for resort is more distorted than city hotels.

# %%
hotel_bookings["month"]=hotel_bookings["reservation_status_date"].dt.month
plt.figure(figsize=(20,10))
plt.title("Month vs booking-cancelation",fontsize=20)
sns.countplot(x='month', hue = 'is_canceled',data=hotel_bookings)
# Out:
# <AxesSubplot:title={'center':'Month vs booking-cancelation'}, xlabel='month', ylabel='count'>

# %% [markdown]
# We can see that the most cancelation takes place in January, but least in August and September.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="month",y="adr",data=hotel_bookings[hotel_bookings["is_canceled"]==1].groupby("month")[["adr"]].sum().reset_index())
plt.title("ADR per month", fontsize=20)
# Out:
# Text(0.5, 1.0, 'ADR per month')

# %% [markdown]
# As we show cancelation are more in January, so is the ADR and similarly lowest adr are in August and September so is the cancelation rate

# %%
top_10_countries = hotel_bookings[hotel_bookings["is_canceled"]==1]["country"].value_counts()[:10]
plt.figure(figsize=(10,5))
plt.title("Top 10 counties with cancelation")
plt.pie(top_10_countries,autopct='%.2f',labels=top_10_countries.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x2086828e1c0>,
# ...
#  [Text(-0.6485414980270044, 0.888478432679651, 'PRT'),
#   Text(-0.12452901505974424, -1.0929284168728757, 'GBR'),
#   Text(0.2795827699816853, -1.0638766257087182, 'ESP'),
#   Text(0.6082427774650023, -0.9165373553007318, 'FRA'),
#   Text(0.8244337697170071, -0.7282231521657391, 'ITA'),
#   Text(0.9549224064682716, -0.5460065911917595, 'DEU'),
#   Text(1.0312598327523899, -0.38275730868464564, 'IRL'),
#   Text(1.0729025706347506, -0.24265216653750293, 'BRA'),
#   Text(1.0926161903610716, -0.12723938290033737, 'USA'),
#   Text(1.0992090719340442, -0.041706308610296686, 'BEL')],
#  [Text(-0.35374990801472966, 0.48462459964344595, '70.07'),
#   Text(-0.06792491730531504, -0.5961427728397503, '6.25'),
#   Text(0.1524996927172829, -0.5802963412956644, '5.54'),
#   Text(0.331768787708183, -0.49992946652767184, '4.93'),
#   Text(0.44969114711836744, -0.39721262845403943, '3.39'),
#   Text(0.5208667671645117, -0.297821777013687, '3.10'),
# ...

# %% [markdown]
# Pie chart cearly showcases the most number of cancelations takes place in Portugal by far.

# %%
hotel_bookings["market_segment"].value_counts(normalize=True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %% [markdown]
# Most Booking takes place by online mode

# %%
hotel_bookings[hotel_bookings["is_canceled"]==1]["market_segment"].value_counts(normalize=True)
# Out:
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: market_segment, dtype: float64

# %% [markdown]
# At the same time, most cancelation is done by onlie users

# %%
# Checkng adr's for cancelation and non-canceled bookings
is_canceled_adr = hotel_bookings[(hotel_bookings["is_canceled"]==1) & (hotel_bookings["reservation_status_date"]>"2016") & (hotel_bookings["reservation_status_date"]<"2017-09")].groupby("reservation_status_date")[["adr"]].mean()
not_canceled_adr = hotel_bookings[(hotel_bookings["is_canceled"]==0) & (hotel_bookings["reservation_status_date"]>"2016") & (hotel_bookings["reservation_status_date"]<"2017-09")].groupby("reservation_status_date")[["adr"]].mean()

# %%
plt.figure(figsize=(20,10))
plt.title("ADR of canceled and non-canceled bookings", fontsize=20)
plt.plot(is_canceled_adr.index,is_canceled_adr["adr"],label="Is Canceled")
plt.plot(not_canceled_adr.index,not_canceled_adr["adr"],label="Not Canceled")
plt.legend()

# %% [markdown]
# This line plot clearly demonstrates more the adr, more the cancelation and above EDA also proves City otel and Portugal are major contributors as well. Thus, by monitoring adr most of the cancelation can be contained.

# %% [markdown]
# ### Thanks!!
